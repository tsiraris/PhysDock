# %% [markdown]
# # PhysDock quickstart
# Run the CPU-only core here; do GPU stages (03/04) from a terminal on the g5 box.
# See ../docs/AWS_RUNBOOK.md for the disciplined, budget-safe sequence.

# %%
import sys; sys.path.insert(0, '..')
from physdock import chem
v = chem.evaluate_ligand('sotorasib_demo', 'CC(=O)Oc1ccccc1C(=O)O')
print(v)

# %%
# Stage 01-02 (CPU, needs network):
# !python ../scripts/01_prepare_target.py --config ../configs/kras_g12c.yaml
# !python ../scripts/02_chem_gate.py --config ../configs/kras_g12c.yaml

# %%
# After GPU stages 03/04 + CPU 05/06/07:
import pandas as pd
# pd.read_csv('../results/report/merged.csv')
